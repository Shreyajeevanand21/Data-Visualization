# %%
pip install matplotlib seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# Import necessary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the TikTok video performance dataset
data = pd.read_csv('tiktok_performance.csv')

# COMPARISON PLOTS

# Bar Plot
plt.figure(figsize=(10, 6))
sns.barplot(x='Category', y='Views', data=data, estimator=np.mean, ci=None)
plt.title('Average Views per Category')
plt.xlabel('Category')
plt.ylabel('Average Views')
plt.xticks(rotation=45)
plt.show()

# Box Plot
plt.figure(figsize=(10, 6))
sns.boxplot(x='Category', y='Likes', data=data)
plt.title('Distribution of Likes per Category')
plt.xlabel('Category')
plt.ylabel('Likes')
plt.xticks(rotation=45)
plt.show()

# Line Plot
data['Upload_Date'] = pd.to_datetime(data['Upload_Date']) 
data_sorted = data.sort_values('Upload_Date')

plt.figure(figsize=(10, 6))
plt.plot(data_sorted['Upload_Date'], data_sorted['Views'], marker='o')
plt.title('Views Over Time')
plt.xlabel('Upload Date')
plt.ylabel('Views')
plt.xticks(rotation=45)
plt.show()

#Scatter Plot
plt.figure(figsize=(10, 6))
plt.scatter(data['Views'], data['Likes'], alpha=0.6, edgecolors='w', s=100)
plt.title('Likes vs Views')
plt.xlabel('Views')
plt.ylabel('Likes')
plt.show()

# COMPOSITION PLOTS

#Pie Chart
category_counts = data['Category'].value_counts()

plt.figure(figsize=(8, 8))
plt.pie(category_counts, labels=category_counts.index, autopct='%1.1f%%', startangle=90, colors=sns.color_palette('pastel'))
plt.title('Distribution of Videos by Category')
plt.show()

#Stacked Bar Plot
engagement_columns = ['Likes', 'Comments', 'Shares']
engagement_totals = data.groupby('Category')[engagement_columns].sum()

# Plot the stacked bar chart
engagement_totals.plot(kind='bar', stacked=True, figsize=(10, 6), color=['#FF9999', '#66B2FF', '#99FF99'])
plt.title('Composition of Engagement (Likes, Comments, Shares) per Category')
plt.xlabel('Category')
plt.ylabel('Total Engagement')
plt.xticks(rotation=45)
plt.legend(loc='upper right')
plt.show()

#Donut Chart
plt.figure(figsize=(8, 8))
plt.pie(category_counts, labels=category_counts.index, autopct='%1.1f%%', startangle=90, colors=sns.color_palette('pastel'), wedgeprops=dict(width=0.4))
plt.title('Donut Chart - Videos by Category')
plt.show()

#Area Plot
plt.figure(figsize=(10, 6))
data_sorted.set_index('Upload_Date', inplace=True)
data_sorted[['Views']].plot(kind='area', alpha=0.5)
plt.title('Views Over Time (Area Plot)')
plt.xlabel('Date')
plt.ylabel('Views')
plt.show()
# Out:
# C:\Users\Kavyashree\AppData\Local\Temp\ipykernel_134836\4032970675.py:14: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='Category', y='Views', data=data, estimator=np.mean, ci=None)

# %%
# Import necessary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the TikTok video performance dataset
data = pd.read_csv('tiktok_performance.csv') 

# Selecting the first few rows of the data for plotting 
print(data.head())
# Out:
#    Video_ID  User_ID Username      Video_Title  Category  Likes  Comments  \
# 0       101        1    user1  Dance Challenge     Dance   1500       120
# 1       102        2    user2       Funny Skit    Comedy   2300       200
# 2       103        3    user3         Tutorial  Tutorial   1200       150
# 3       104        4    user4      Viral Dance     Dance   4500       500
# 4       105        5    user5    Comedy Sketch    Comedy   1800       180
#
#    Shares  Views Upload_Date  Video_Length   Hashtags  User_Followers  \
# 0     300  50000  2024-08-01            30     #dance            1500
# 1     400  70000  2024-08-02            45     #funny            2000
# 2     250  40000  2024-08-03            60  #tutorial            1200
# 3     600  90000  2024-08-04            30     #viral            1800
# 4     210  50000  2024-08-05            45    #comedy            1500
#
#    User_Following  User_Likes
# 0             300        5000
# 1             500        6000
# ...

# %%
# Bar Plot
plt.figure(figsize=(10, 6))
sns.barplot(x='Category', y='Views', data=data, estimator=np.mean, ci=None)
plt.title('Average Views per Category')
plt.xlabel('Category')
plt.ylabel('Average Views')
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\Kavyashree\AppData\Local\Temp\ipykernel_134836\570848806.py:3: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='Category', y='Views', data=data, estimator=np.mean, ci=None)

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='Category', y='Likes', data=data)
plt.title('Distribution of Likes per Category')
plt.xlabel('Category')
plt.ylabel('Likes')
plt.xticks(rotation=45)
plt.show()

# %%
# Line Plot
data['Upload_Date'] = pd.to_datetime(data['Upload_Date']) 
data_sorted = data.sort_values('Upload_Date')

plt.figure(figsize=(10, 6))
plt.plot(data_sorted['Upload_Date'], data_sorted['Views'], marker='o')
plt.title('Views Over Time')
plt.xlabel('Upload Date')
plt.ylabel('Views')
plt.xticks(rotation=45)
plt.show()

# %%
#Scatter Plot
plt.figure(figsize=(10, 6))
plt.scatter(data['Views'], data['Likes'], alpha=0.6, edgecolors='w', s=100)
plt.title('Likes vs Views')
plt.xlabel('Views')
plt.ylabel('Likes')
plt.show()

# %%
#pie Chart
category_counts = data['Category'].value_counts()

plt.figure(figsize=(8, 8))
plt.pie(category_counts, labels=category_counts.index, autopct='%1.1f%%', startangle=90, colors=sns.color_palette('pastel'))
plt.title('Distribution of Videos by Category')
plt.show()

# %%
#Donut Chart
plt.figure(figsize=(8, 8))
plt.pie(category_counts, labels=category_counts.index, autopct='%1.1f%%', startangle=90, colors=sns.color_palette('pastel'), wedgeprops=dict(width=0.4))
plt.title('Donut Chart - Videos by Category')
plt.show()

# %%
#Stacked Bar Plot
engagement_columns = ['Likes', 'Comments', 'Shares']
engagement_totals = data.groupby('Category')[engagement_columns].sum()

# Plot the stacked bar chart
engagement_totals.plot(kind='bar', stacked=True, figsize=(10, 6), color=['#FF9999', '#66B2FF', '#99FF99'])
plt.title('Composition of Engagement (Likes, Comments, Shares) per Category')
plt.xlabel('Category')
plt.ylabel('Total Engagement')
plt.xticks(rotation=45)
plt.legend(loc='upper right')
plt.show()

# %%
#Area Plot
plt.figure(figsize=(10, 6))
data_sorted.set_index('Upload_Date', inplace=True)
data_sorted[['Views']].plot(kind='area', alpha=0.5)
plt.title('Views Over Time (Area Plot)')
plt.xlabel('Date')
plt.ylabel('Views')
plt.show()
